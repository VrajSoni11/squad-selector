# %%
# !pip install requests beautifulsoup4 pandas lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (4.13.5)
# Requirement already satisfied: pandas in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (2.3.2)
# Requirement already satisfied: lxml in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (6.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\vraj soni\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

print("✅ Setup Ready")
# Out:
# ✅ Setup Ready

# %%
def get_page(url):
    response = requests.get(url)
    
    if response.status_code == 200:
        print("✅ Page Loaded")
        return BeautifulSoup(response.text, "lxml")
    else:
        print("❌ Failed:", response.status_code)
        return None

# %%
url = "http://books.toscrape.com/"
soup = get_page(url)

print(soup.title.text)
# Out:
# ✅ Page Loaded
#
#     All products | Books to Scrape - Sandbox

# %%
def scrape_books():
    url = "http://books.toscrape.com/"
    soup = get_page(url)
    
    books = []
    
    items = soup.find_all("article", class_="product_pod")
    
    for item in items:
        name = item.h3.a["title"]
        price = item.find("p", class_="price_color").text
        rating = item.p["class"][1]
        
        books.append({
            "name": name,
            "price": price,
            "rating": rating
        })
    
    return books

# %%
books = scrape_books()

print("Total Books:", len(books))
print(books[:5])
# Out:
# ✅ Page Loaded
# Total Books: 20
# [{'name': 'A Light in the Attic', 'price': 'Â£51.77', 'rating': 'Three'}, {'name': 'Tipping the Velvet', 'price': 'Â£53.74', 'rating': 'One'}, {'name': 'Soumission', 'price': 'Â£50.10', 'rating': 'One'}, {'name': 'Sharp Objects', 'price': 'Â£47.82', 'rating': 'Four'}, {'name': 'Sapiens: A Brief History of Humankind', 'price': 'Â£54.23', 'rating': 'Five'}]

# %%
df = pd.DataFrame(books)
df
# Out:
#                                                  name    price rating
# 0                                A Light in the Attic  Â£51.77  Three
# 1                                  Tipping the Velvet  Â£53.74    One
# 2                                          Soumission  Â£50.10    One
# 3                                       Sharp Objects  Â£47.82   Four
# 4               Sapiens: A Brief History of Humankind  Â£54.23   Five
# 5                                     The Requiem Red  Â£22.65    One
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34   Four
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93  Three
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60   Four
# 9                                     The Black Maria  Â£52.15    One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99    Two
# 11                              Shakespeare's Sonnets  Â£20.66   Four
# 12                                        Set Me Free  Â£17.46   Five
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...  Â£52.29   Five
# 14                          Rip it Up and Start Again  Â£35.02   Five
# 15  Our Band Could Be Your Life: Scenes from the A...  Â£57.25  Three
# 16                                               Olio  Â£23.88    One
# 17  Mesaerion: The Best Science Fiction Stories 18...  Â£37.59    One
# 18                       Libertarianism for Beginners  Â£51.33    Two
# 19                            It's Only the Himalayas  Â£45.17    Two
